# %%
import pandas as pd
import numpy as np
import re
from gensim.models import Word2Vec
M= pd.read_csv("/home/her/Desktop/nlp/codes/reviews_Baby_5_final_dataset.csv")
df = pd.DataFrame(M)
df1=df["reviewText"]
df2=df["summary"]
df3=pd.concat([df1,df2],axis=1)

df3=np.array(df3)
df3[2]
# Out:
# array(["I like this log, but think it would work better with clearer AM & PM sections. Each page is 12 hours so you really need two pages a day if your baby feeds or wets a lot in the early morning hours between midnight and 7am. We're cramming those in to the 2 blank spaces above 7am right now.",
#        'Needs clearer AM & PM'], dtype=object)

# %%
df1=np.array(df1)
df2=np.array(df2)
sentence=[]
for i in range(len(df1)):
    a=re.sub(r'[",''/?&*!1234567890]', ' ', df1[i])
    sentence.append((a.lower()).split())
# print(sentence)

# %%
# !cat /home/her/Desktop/nlp/codes/review.txt |less
# Out:
# This book is perfect!  I'm a first time new mom, and this book made it so easy to keep track of feedings, diaper changes, sleep.  Definitely would recommend this for new moms.  Plus it's small enough that I throw in the diaper back for doctor visits.
# I use this so that our babysitter (grandma) can keep track of what goes on during the day.  We've recorded so many milestones since we received this.  It is a 6 month diary and has room for notes.  I wish the hours started around 6 am and went until 8 pm, but we just write over certain times to suit our purposes. The nice thing is that if we had a rough night and we are super tired, we have something to refer to if we forgot when we last fed the baby or when he woke up. I also like that the front page has a place for emergency comments and a consent form in case your child needs medical care.  It also has a place at the back of the book for immunizations.  I'll definitely get another one in 6 months when we finish this book.
# I like this log, but think it would work better with clearer AM & PM sections. Each page is 12 hours so you really need two pages a day if your baby feeds or wets a lot in the early morning hours between midnight and 7am. We're cramming those in to the 2 blank spaces above 7am right now.
# : and I have a six month old baby boy and around the 4-month mark my wife decided that she would return to work instead of being a stay-at-home mom. We hired an in-home nanny to care for our little boy and the arrangement has worked quite well ever since. Shortly after starting the arrangement we realized that we would need some sort of journal to track our little boy's activities while he w:

# %%
model = Word2Vec(sentence,size=3, min_count=1)

# %%
print(model)
words = list(model.wv.vocab)
print((words))
# Out:
# Word2Vec(vocab=136212, size=3, alpha=0.025)
# ['this', 'book', 'is', 'perfect', "i'm", 'a', 'first', 'time', 'new', 'mom', 'and', 'made', 'it', 'so', 'easy', 'to', 'keep', 'track', 'of', 'feedings', 'diaper', 'changes', 'sleep.', 'definitely', 'would', 'recommend', 'for', 'moms.', 'plus', "it's", 'small', 'enough', 'that', 'i', 'throw', 'in', 'the', 'back', 'doctor', 'visits.', 'use', 'our', 'babysitter', '(grandma)', 'can', 'what', 'goes', 'on', 'during', 'day.', "we've", 'recorded', 'many', 'milestones', 'since', 'we', 'received', 'this.', 'month', 'diary', 'has', 'room', 'notes.', 'wish', 'hours', 'started', 'around', 'am', 'went', 'until', 'pm', 'but', 'just', 'write', 'over', 'certain', 'times', 'suit', 'purposes.', 'nice', 'thing', 'if', 'had', 'rough', 'night', 'are', 'super', 'tired', 'have', 'something', 'refer', 'forgot', 'when', 'last', 'fed', 'baby', 'or', 'he', 'woke', 'up.', 'also', 'like', 'front', 'page', 'place', 'emergency', 'comments', 'consent', 'form', 'case', 'your', 'child', 'needs', 'medical', 'care.', 'at', 'immunizations.', "i'll", 'get', 'another', 'one', 'months', 'finish', 'book.', 'log', 'think', 'work', 'better', 'with', 'clearer', 'sections.', 'each', 'you', 'really', 'need', 'two', 'pages', 'day', 'feeds', 'wets', 'lot', 'early', 'morning', 'between', 'midnight', 'am.', "we're", 'cramming', 'those', 'blank', 'spaces', 'above', 'right', 'now.', 'my', 'wife', 'six', 'old', 'boy', '-month', 'mark', 'decided', 'she', 'return', 'instead', 'being', 'stay-at-home', 'mom.', 'hired', 'an', 'in-home', 'nanny', 'care', 'little', 'arrangement', 'worked', 'quite', 'well', 'ever', 'since.', 'shortly', 'after', 'starting', 'realized', 'some', 'sort', 'journal', "boy's", 'activities', 'while', 'was', 'were', 'working.', 'used', 'plain', 'notebook', 'period', 'weeks', 'stumbled', 'tracker', '-', 'daily', 'childcare', 'journal.--------------------layout', 'use:the', 'excellent', 'idea.', 'clearly', 'divided', 'into', 'columns', 'tracking', 'nap-time', 'play-time', 'as', 'general', 'areas', 'notes', 'milestones.', 'legibility', 'huge', 'improvement', 'standard', 'entries', 'ended', 'up', 'becoming', 'paragraphs.', 'few', 'short', 'moments', 'summarize', 'all', 'data', 'totals', 'section', 'determine', 'key', 'information', 'how', 'much', 'did', 'eat', 'bowel', 'movement', 'sleep', 'they', 'etc.there', 'however', 'frustrating', 'limitations', 'journal.', 'entire', 'layout', 'about', 'half', 'sheet', 'down', 'middle', '(portrait', 'layout).', 'constrains', 'very', 'column', 'row.', 'okay', 'be', 'summarized', 'ounces;', 'by', '#', ';#', ';', 'on.', 'once', 'becomes', 'more', 'active', "you'd", 'know', 'than', ';tummy', 'under', 'things', 'start', 'tight', 'page.another', 'problem', 'only', 'covers', 'out', "baby's", "that's", 'fine', 'intention', 'providers.', 'wanted', 'which', 'often', 'starts', 'earlier', 'using', 'require', 'second', 'page.--------------------what', 'tracker:(+)', 'good', 'read', 'instantly', 'gather', 'matter', 'moments(+)', 'high', 'quality', 'paper(+)', 'consistent', 'pages--------------------what', "don't", 'tracker:(-)', 'expensive', 'gets', 'most', '-months', 'less', 'babies', 'day(-)', 'cover', 'thick', 'not', 'hardback', 'bends', 'easily', 'bag(-)', 'should', 'bigger.', 'understand', 'portability', 'concern', 'current', 'size', 'entirely', 'too', 'small--------------------conclusion:i', 'making', 'own', 'format', 'spreadsheet', 'includes', '-hour', 'space', 'along', 'other', 'bound', 'cheaply', 'local', 'shop.', 'adequate', 'because', 'size.', 'son', 'born.', 'great', 'handy', 'way', 'eats', 'change', 'his', 'diaper.', 'makes', 'discuss', 'progress', 'doctor.', 'grandparents', 'who', 'watch', 'him', 'gone.', 'able', 'maintain', 'schedule', 'me', 'see', 'doing', 'work.', 'highly', 'parents', 'children', 'especially', 'ones', 'year', 'age.', 'continue', 'buy', 'every', 'least', 'old.', 'been', 'helpful', 'naps', 'developmental', 'laid', 'could', 'leave', 'open', 'left', 'side', 'pm.', 'set', 'flip', 'full', '(starts', 'a.m.', 'right) ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
M= pd.read_csv("/home/her/Desktop/nlp/codes/category_tree.csv")
df = pd.DataFrame(M)
print(df[:5])
df1=df["parentid"]
df2=df["categoryid"]
c=np.array(df1)
d=np.array(df2)

plt.hist(c)
plt.show()
plt.hist(d)
plt.show()

# df1=df["reviewText"]
# df2=df["summary"]
# df3=pd.concat([df1,df2],axis=1)
# df3[:3]
# Out:
#    categoryid  parentid
# 0        1016     213.0
# 1         809     169.0
# 2         570       9.0
# 3        1691     885.0
# 4         536    1691.0

# %%
class DPPpicard(object):
    def __init__(self,review,summary):
        self.review=review
        self.summary=summary
    def fixed_point_map(self):
