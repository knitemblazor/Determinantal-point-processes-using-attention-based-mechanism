# %%
import pandas as pd
import numpy as np
import re
from gensim.models import Word2Vec
M= pd.read_csv("/home/her/Desktop/nlp/codes/reviews_Baby_5_final_dataset.csv")
df = pd.DataFrame(M)
df1=df["reviewText"]
df2=df["summary"]
df3=pd.concat([df1,df2],axis=1)

df3=np.array(df3)
df3[2]
# Out:
# array(["I like this log, but think it would work better with clearer AM & PM sections. Each page is 12 hours so you really need two pages a day if your baby feeds or wets a lot in the early morning hours between midnight and 7am. We're cramming those in to the 2 blank spaces above 7am right now.",
#        'Needs clearer AM & PM'], dtype=object)

# %%
df1=np.array(df1)
df2=np.array(df2)
se
for i in range(len(df1)):
    a=re.sub(r'[",''/?&*!1234567890]', ' ', df1[i])
    
      f.write("%s\n" % a)

# %%
# !cat /home/her/Desktop/nlp/codes/review.txt |less
# Out:
# This book is perfect!  I'm a first time new mom, and this book made it so easy to keep track of feedings, diaper changes, sleep.  Definitely would recommend this for new moms.  Plus it's small enough that I throw in the diaper back for doctor visits.
# I use this so that our babysitter (grandma) can keep track of what goes on during the day.  We've recorded so many milestones since we received this.  It is a 6 month diary and has room for notes.  I wish the hours started around 6 am and went until 8 pm, but we just write over certain times to suit our purposes. The nice thing is that if we had a rough night and we are super tired, we have something to refer to if we forgot when we last fed the baby or when he woke up. I also like that the front page has a place for emergency comments and a consent form in case your child needs medical care.  It also has a place at the back of the book for immunizations.  I'll definitely get another one in 6 months when we finish this book.
# ...

# %%
from textblob import TextBlob
import sys  
from importlib import reload
reload(sys)  
sys.getdefaultencoding()
file=open("/home/her/Desktop/nlp/codes/review.txt");
t=file.read();
print(type(t))
bobo = TextBlob(t)
bobo.tags
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-73393a83972d> in <module>
#       8 print(type(t))
#       9 bobo = TextBlob(t)
# ---> 10 bobo.tags
#
# ~/bhavya/lib/python3.6/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/bhavya/lib/python3.6/site-packages/textblob/blob.py in pos_tags(self)
#     482         """
#     483         if isinstance(self, TextBlob):
# --> 484             return [val for sublist in [s.pos_tags for s in self.sentences] for val in sublist]
#     485         else:
#     486             return [(Word(unicode(word), pos_tag=t), unicode(t))
#
# ~/bhavya/lib/python3.6/site-packages/textblob/blob.py in <listcomp>(.0)
# ...

# %%
bobo.sentences
# Out:
# [Sentence("This book is perfect!"),
#  Sentence("I'm a first time new mom, and this book made it so easy to keep track of feedings, diaper changes, sleep."),
#  Sentence("Definitely would recommend this for new moms."),
#  Sentence("Plus it's small enough that I throw in the diaper back for doctor visits."),
#  Sentence("I use this so that our babysitter (grandma) can keep track of what goes on during the day."),
#  Sentence("We've recorded so many milestones since we received this."),
#  Sentence("It is a 6 month diary and has room for notes."),
#  Sentence("I wish the hours started around 6 am and went until 8 pm, but we just write over certain times to suit our purposes."),
#  Sentence("The nice thing is that if we had a rough night and we are super tired, we have something to refer to if we forgot when we last fed the baby or when he woke up."),
# ...

# %%
model = Word2Vec(bobo.sentences,size=3, min_count=1)

# %%
print(model)
words = list(model.wv.vocab)
print((words))
# Out:
# Word2Vec(vocab=95, size=3, alpha=0.025)
# ['T', 'h', 'i', 's', ' ', 'b', 'o', 'k', 'p', 'e', 'r', 'f', 'c', 't', '!', 'I', "'", 'm', 'a', 'n', 'w', ',', 'd', 'y', 'g', 'l', '.', 'D', 'u', 'P', 'v', '(', ')', 'W', '6', '8', 'j', 'z', 'A', 'M', '&', 'E', '1', '2', '7', 'x', '4', '-', 'q', 'S', 'B', 'C', 'J', 'L', 'Y', 'O', 'U', 'N', ':', 'F', ';', '#', '3', 'H', 'K', 'R', '+', 'G', '0', '/', '\n', '5', 'Z', 'V', '?', 'Q', '9', '[', ']', '*', '$', 'X', '@', '%', '>', '=', '_', '~', '{', '}', '^', '`', '\\', '\x10', '|']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
M= pd.read_csv("/home/her/Desktop/nlp/codes/category_tree.csv")
df = pd.DataFrame(M)
print(df[:5])
df1=df["parentid"]
df2=df["categoryid"]
c=np.array(df1)
d=np.array(df2)

plt.hist(c)
plt.show()
plt.hist(d)
plt.show()

# df1=df["reviewText"]
# df2=df["summary"]
# df3=pd.concat([df1,df2],axis=1)
# df3[:3]
# Out:
#    categoryid  parentid
# 0        1016     213.0
# 1         809     169.0
# 2         570       9.0
# 3        1691     885.0
# 4         536    1691.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
M= pd.read_csv("/home/her/Desktop/nlp/codes/LowRankDPP.jl-master/data/Amazon-baby-registry/1_100_100_100_apparel_regs.csv")
df = pd.DataFrame(M)
# print(df)
# df1=df["parentid"]
# df2=df["categoryid"]
# c=np.array(df1)
# d=np.array(df2)

# plt.hist(c)
# plt.show()
# plt.hist(d)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-20-df2cb4a2b940> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 M= pd.read_csv("/home/her/Desktop/nlp/codes/LowRankDPP.jl-master/data/Amazon-baby-registry/1_100_100_100_apparel_regs.csv")
#       5 df = pd.DataFrame(M)
#       6 print(df)
#
# ...

# %%
class DPPpicard(object):
    def __init__(self,review,summary):
        self.review=review
        self.summary=summary
    def fixed_point_map(self):
